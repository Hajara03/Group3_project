# %% [markdown]
# <a href="https://colab.research.google.com/github/Hajara03/Group3_project/blob/main/Group_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.Loading dataset

# %%
df=pd.read_csv('/content/House_Pricing.csv')
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %% [markdown]
# 2.Data Visualisation

# %%
# Visualisation of Sale Price distribution using Histplot
plt.figure(figsize=(10, 8))
sns.histplot(df['Sale Price'].dropna(),kde=True,bins=30,color='red')
plt.xlabel('Sale Price')
plt.ylabel('count')
plt.show()

# %%
# Visualisation of Sale Price vs Flat Area using Scatterplot
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='Flat Area (in Sqft)',y='Sale Price',alpha=0.9, color='red')
plt.xlabel('Flat Area (in Sqft)')
plt.ylabel('Sale Price')
plt.show()

# %%
#Visualisation Number of Bedrooms vs Sale Price using Barplot
plt.figure(figsize=(10,5))
sns.barplot(data=df,x='No of Bedrooms',y='Sale Price',errorbar=None)
plt.xlabel('Number of Bedrooms')
plt.ylabel('Sale Price')
plt.show()

# %% [markdown]
# 3.Understand the data

# %%
#shape
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['ID', 'Date House was Sold', 'Sale Price', 'No of Bedrooms',
#        'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)',
#        'No of Floors', 'Waterfront View', 'No of Times Visited',
#        'Condition of the House', 'Overall Grade',
#        'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)',
#        'Age of House (in Years)', 'Renovated Year', 'Zipcode', 'Latitude',
#        'Longitude', 'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
#Datatype
df.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
#Statistical Information
df.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
#Target Variable
target_variable= df["Sale Price"]
target_variable.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: Sale Price, dtype: float64

# %%
#Numeric Columns
df.select_dtypes(include='number').columns
# Out:
# Index(['ID', 'Sale Price', 'No of Bedrooms', 'No of Bathrooms',
#        'Flat Area (in Sqft)', 'Lot Area (in Sqft)', 'No of Floors',
#        'Overall Grade', 'Area of the House from Basement (in Sqft)',
#        'Basement Area (in Sqft)', 'Age of House (in Years)', 'Renovated Year',
#        'Zipcode', 'Latitude', 'Longitude',
#        'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
#Categorical Columns
df.select_dtypes(include='object').columns
# Out:
# Index(['Date House was Sold', 'Waterfront View', 'No of Times Visited',
#        'Condition of the House'],
#       dtype='object')

# %% [markdown]
# Detect and Handle Missing Values

# %%
#find missing  values per column

df.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
#check the percentage

df.isna().sum()/len(df)*100
# Out:
# ID                                            0.000000
# Date House was Sold                           0.000000
# Sale Price                                    0.018507
# No of Bedrooms                                0.000000
# No of Bathrooms                               0.018507
# Flat Area (in Sqft)                           0.041642
# Lot Area (in Sqft)                            0.041642
# No of Floors                                  0.000000
# Waterfront View                               0.000000
# No of Times Visited                          90.172581
# Condition of the House                        0.000000
# Overall Grade                                 0.000000
# Area of the House from Basement (in Sqft)     0.013881
# Basement Area (in Sqft)                       0.000000
# Age of House (in Years)                       0.000000
# Renovated Year                                0.000000
# Zipcode                                       0.004627
# ...

# %%
# Drop column with more than 60%-70% missing values
df.drop(columns=['No of Times Visited'], inplace=True)

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=df["Sale Price"], kde=True, bins=30, color="blue")
plt.title("Sale Price")
plt.show()

# %%
median_result=df["Sale Price"].median()
median_result
# Out:
# 450000.0

# %%
df["Sale Price"]=df["Sale Price"].fillna(median_result)

# %%
df.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %% [markdown]
# Detect and Handle Outliers

# %%
columns=df.columns
plt.figure(figsize=(20,33))

for i,col in enumerate(columns):
  plt.subplot(len(columns),3,i+1)
  sns.boxplot(x=df[col])
  plt.title(f"Box plot-{col}")

plt.tight_layout()
plt.show()

# %%
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers, lower_bound, upper_bound

outliers, low, high = detect_outliers_iqr(df, 'Sale Price')
print(f"Found {len(outliers)} outliers outside [{low:.2f}, {high:.2f}]")
# Out:
# Found 1159 outliers outside [-162500.00, 1129500.00]

# %% [markdown]
# Encode categorical features

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %% [markdown]
# encoding

# %%
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    print(col)
    print(df[col].unique())

# %%
df=pd.get_dummies(
    df,
    columns=cat_cols, dtype=int,
    drop_first=True
)

# %%
df.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0               1180.0              5650.0           1.0              7
# 1               2570.0              7242.0           2.0              7
# 2                770.0             10000.0           1.0              6
# 3               1960.0              5000.0           1.0              7
# 4               1680.0              8080.0           1.0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# 0                                     1180.0                        0  ...
# ...

# %% [markdown]
# Feature Selection

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr_result = df.corr(numeric_only=True)

plt.figure(figsize=(10, 8))

sns.heatmap(
    corr_result,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# Train Test split

# %%
from sklearn.model_selection import train_test_split

# %%
X=df[["No of Bathrooms","Flat Area (in Sqft)","Overall Grade","Area of the House from Basement (in Sqft)"]]
y=df["Sale Price"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=42)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("X_train_scaled shape:", X_train_scaled.shape)
print("X_test_scaled shape:", X_test_scaled.shape)
# Out:
# X_train_scaled shape: (17290, 4)
# X_test_scaled shape: (4323, 4)
